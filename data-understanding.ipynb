# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("./Dataset/Train_HR_Employee_Attrition.csv")

# %%
#attributi numerici
num_attr= ['Age','DailyRate','DistanceFromHome','HourlyRate','MonthlyIncome','MonthlyRate','NumCompaniesWorked',
           'PercentSalaryHike','TotalWorkingYears','TrainingTimesLastYear','YearsAtCompany','YearsInCurrentRole',
           'YearsSinceLastPromotion','YearsWithCurrManager',]

#attributi categorici
cat_attr = ['Attrition','BusinessTravel','Department','Education','EducationField','EnvironmentSatisfaction',
            'Gender','JobInvolvement','JobLevel','JobRole','JobSatisfaction','MaritalStatus','Over18','OverTime',
            'PerformanceRating','RelationshipSatisfaction','StandardHours','StockOptionLevel','WorkLifeBalance']

# %%
#Stats di tutti gli attributi numerici
for attr in num_attr:
    print(f"{attr}\n{df[attr].describe()}\n\n")
# Out:
# Age
# count    1000.000000
# mean       37.199000
# std         9.015802
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64
#
#
# DailyRate
# count    1176.000000
# mean      803.650510
# std       406.683045
# min       102.000000
# 25%       460.500000
# 50%       804.000000
# 75%      1169.000000
# max      1499.000000
# Name: DailyRate, dtype: float64
#
#
# DistanceFromHome
# count    1176.000000
# mean        9.210034
# std         8.097024
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64
#
#
# HourlyRate
# count    1176.000000
# mean       66.299320
# std        20.266116
# min        30.000000
# 25%        49.000000
# 50%        66.000000
# 75%        84.000000
# max       100.000000
# Name: HourlyRate, dtype: float64
#
#
# MonthlyIncome
# count      963.000000
# mean      6565.946002
# std       4710.625603
# min       1009.000000
# 25%       2969.000000
# 50%       4969.000000
# 75%       8585.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64
#
#
# MonthlyRate
# count     1176.000000
# mean     14395.836735
# std       7111.845106
# min       2097.000000
# 25%       8227.250000
# 50%      14434.000000
# 75%      20489.250000
# max      26999.000000
# Name: MonthlyRate, dtype: float64
#
#
# NumCompaniesWorked
# count    1176.000000
# mean        2.663265
# std         2.491287
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max         9.000000
# Name: NumCompaniesWorked, dtype: float64
#
#
# PercentSalaryHike
# count    1176.000000
# mean       15.176871
# std         3.623941
# min        11.000000
# 25%        12.000000
# 50%        14.000000
# 75%        18.000000
# max        25.000000
# Name: PercentSalaryHike, dtype: float64
#
#
# TotalWorkingYears
# count    1176.000000
# mean       11.019558
# std         7.694848
# min         0.000000
# 25%         6.000000
# 50%        10.000000
# 75%        15.000000
# max        40.000000
# Name: TotalWorkingYears, dtype: float64
#
#
# TrainingTimesLastYear
# count    943.000000
# mean       2.827147
# std        1.273120
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        6.000000
# Name: TrainingTimesLastYear, dtype: float64
#
#
# YearsAtCompany
# count    1116.000000
# mean        6.926523
# std         6.063193
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         9.000000
# max        40.000000
# Name: YearsAtCompany, dtype: float64
#
#
# YearsInCurrentRole
# count    1176.000000
# mean        4.188776
# std         3.637405
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         7.000000
# max        18.000000
# Name: YearsInCurrentRole, dtype: float64
#
#
# YearsSinceLastPromotion
# count    1176.000000
# mean        2.171769
# std         3.189785
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         3.000000
# max        15.000000
# Name: YearsSinceLastPromotion, dtype: float64
#
#
# YearsWithCurrManager
# count    1176.000000
# mean        4.107993
# std         3.601097
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         7.000000
# max        17.000000
# Name: YearsWithCurrManager, dtype: float64

# %%
#Stats di tutti gli attributi categorici
for attr in cat_attr:
    print(f"**{attr}\n{df[attr].describe()}")
    print(f"\n{attr} Classes")
    print(df[attr].value_counts(normalize=True))
    print(df[attr].value_counts(normalize=False))
    print(f"\n\n")
# Out:
# **Attrition
# count     1176
# unique       2
# top         No
# freq       984
# Name: Attrition, dtype: object
#
# Attrition Classes
# No     0.836735
# Yes    0.163265
# Name: Attrition, dtype: float64
# No     984
# Yes    192
# Name: Attrition, dtype: int64
#
#
#
# **BusinessTravel
# count              1069
# unique                3
# top       Travel_Rarely
# freq                764
# Name: BusinessTravel, dtype: object
#
# BusinessTravel Classes
# Travel_Rarely        0.714687
# Travel_Frequently    0.179607
# Non-Travel           0.105706
# Name: BusinessTravel, dtype: float64
# Travel_Rarely        764
# Travel_Frequently    192
# Non-Travel           113
# Name: BusinessTravel, dtype: int64
#
#
#
# **Department
# count                       1176
# unique                         3
# top       Research & Development
# freq                         769
# Name: Department, dtype: object
#
# Department Classes
# Research & Development    0.653912
# Sales                     0.306973
# Human Resources           0.039116
# Name: Department, dtype: float64
# Research & Development    769
# Sales                     361
# Human Resources            46
# Name: Department, dtype: int64
#
#
#
# **Education
# count    1176.000000
# mean        2.884354
# std         1.016574
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: Education, dtype: float64
#
# Education Classes
# 3    0.390306
# 4    0.265306
# 2    0.198980
# 1    0.118197
# 5    0.027211
# Name: Education, dtype: float64
# 3    459
# 4    312
# 2    234
# 1    139
# 5     32
# Name: Education, dtype: int64
#
#
#
# **EducationField
# count              1176
# unique                6
# top       Life Sciences
# freq                489
# Name: EducationField, dtype: object
#
# EducationField Classes
# Life Sciences       0.415816
# Medical             0.314626
# Marketing           0.106293
# Technical Degree    0.090986
# Other               0.054422
# Human Resources     0.017857
# Name: EducationField, dtype: float64
# Life Sciences       489
# Medical             370
# Marketing           125
# Technical Degree    107
# Other                64
# Human Resources      21
# Name: EducationField, dtype: int64
#
#
#
# **EnvironmentSatisfaction
# count    1176.000000
# mean        2.715986
# std         1.088876
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: EnvironmentSatisfaction, dtype: float64
#
# EnvironmentSatisfaction Classes
# 3    0.311224
# 4    0.298469
# 2    0.198129
# 1    0.192177
# Name: EnvironmentSatisfaction, dtype: float64
# 3    366
# 4    351
# 2    233
# 1    226
# Name: EnvironmentSatisfaction, dtype: int64
#
#
#
# **Gender
# count     1117
# unique       2
# top       Male
# freq       664
# Name: Gender, dtype: object
#
# Gender Classes
# Male      0.594449
# Female    0.405551
# Name: Gender, dtype: float64
# Male      664
# Female    453
# Name: Gender, dtype: int64
#
#
#
# **JobInvolvement
# count    1176.000000
# mean        2.735544
# std         0.716228
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         4.000000
# Name: JobInvolvement, dtype: float64
#
# JobInvolvement Classes
# 3    0.583333
# 2    0.257653
# 4    0.103741
# 1    0.055272
# Name: JobInvolvement, dtype: float64
# 3    686
# 2    303
# 4    122
# 1     65
# Name: JobInvolvement, dtype: int64
#
#
#
# **JobLevel
# count    1176.000000
# mean        2.021259
# std         1.069686
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         5.000000
# Name: JobLevel, dtype: float64
#
# JobLevel Classes
# 1    0.379252
# 2    0.364796
# 3    0.148810
# 4    0.069728
# 5    0.037415
# Name: JobLevel, dtype: float64
# 1    446
# 2    429
# 3    175
# 4     82
# 5     44
# Name: JobLevel, dtype: int64
#
#
#
# **JobRole
# count                1176
# unique                  9
# top       Sales Executive
# freq                  261
# Name: JobRole, dtype: object
#
# JobRole Classes
# Sales Executive              0.221939
# Research Scientist           0.204082
# Laboratory Technician        0.180272
# Manufacturing Director       0.097789
# Healthcare Representative    0.090136
# Manager                      0.068878
# Sales Representative         0.058673
# Research Director            0.043367
# Human Resources              0.034864
# Name: JobRole, dtype: float64
# Sales Executive              261
# Research Scientist           240
# Laboratory Technician        212
# Manufacturing Director       115
# Healthcare Representative    106
# Manager                       81
# Sales Representative          69
# Research Director             51
# Human Resources               41
# Name: JobRole, dtype: int64
#
#
#
# **JobSatisfaction
# count    1176.000000
# mean        2.702381
# std         1.101578
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: JobSatisfaction, dtype: float64
#
# JobSatisfaction Classes
# 4    0.301871
# 3    0.298469
# 2    0.199830
# 1    0.199830
# Name: JobSatisfaction, dtype: float64
# 4    355
# 3    351
# 2    235
# 1    235
# Name: JobSatisfaction, dtype: int64
#
#
#
# **MaritalStatus
# count        1176
# unique          3
# top       Married
# freq          542
# Name: MaritalStatus, dtype: object
#
# MaritalStatus Classes
# Married     0.460884
# Single      0.325680
# Divorced    0.213435
# Name: MaritalStatus, dtype: float64
# Married     542
# Single      383
# Divorced    251
# Name: MaritalStatus, dtype: int64
#
#
#
# **Over18
# count     804
# unique      1
# top         Y
# freq      804
# Name: Over18, dtype: object
#
# Over18 Classes
# Y    1.0
# Name: Over18, dtype: float64
# Y    804
# Name: Over18, dtype: int64
#
#
#
# **OverTime
# count     1176
# unique       2
# top         No
# freq       838
# Name: OverTime, dtype: object
#
# OverTime Classes
# No     0.712585
# Yes    0.287415
# Name: OverTime, dtype: float64
# No     838
# Yes    338
# Name: OverTime, dtype: int64
#
#
#
# **PerformanceRating
# count    1038.000000
# mean        3.152216
# std         0.359403
# min         3.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         4.000000
# Name: PerformanceRating, dtype: float64
#
# PerformanceRating Classes
# 3.0    0.847784
# 4.0    0.152216
# Name: PerformanceRating, dtype: float64
# 3.0    880
# 4.0    158
# Name: PerformanceRating, dtype: int64
#
#
#
# **RelationshipSatisfaction
# count    1176.000000
# mean        2.702381
# std         1.092268
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: RelationshipSatisfaction, dtype: float64
#
# RelationshipSatisfaction Classes
# 3    0.301020
# 4    0.297619
# 2    0.207483
# 1    0.193878
# Name: RelationshipSatisfaction, dtype: float64
# 3    354
# 4    350
# 2    244
# 1    228
# Name: RelationshipSatisfaction, dtype: int64
#
#
#
# **StandardHours
# count    606.0
# mean      80.0
# std        0.0
# min       80.0
# 25%       80.0
# 50%       80.0
# 75%       80.0
# max       80.0
# Name: StandardHours, dtype: float64
#
# StandardHours Classes
# 80.0    1.0
# Name: StandardHours, dtype: float64
# 80.0    606
# Name: StandardHours, dtype: int64
#
#
#
# **StockOptionLevel
# count    1176.000000
# mean        0.783163
# std         0.851385
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         3.000000
# Name: StockOptionLevel, dtype: float64
#
# StockOptionLevel Classes
# 0    0.437075
# 1    0.399660
# 2    0.106293
# 3    0.056973
# Name: StockOptionLevel, dtype: float64
# 0    514
# 1    470
# 2    125
# 3     67
# Name: StockOptionLevel, dtype: int64
#
#
#
# **WorkLifeBalance
# count    1176.000000
# mean        2.755952
# std         0.707984
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         4.000000
# Name: WorkLifeBalance, dtype: float64
#
# WorkLifeBalance Classes
# 3    0.610544
# 2    0.231293
# 4    0.101190
# 1    0.056973
# Name: WorkLifeBalance, dtype: float64
# 3    718
# 2    272
# 4    119
# 1     67
# Name: WorkLifeBalance, dtype: int64

# %%
#NIstrogrammi e boxplot di tutti gli attributi numerici - fast view

for attr in num_attr:            
    fig = plt.figure(figsize=(13, 13)) 
    fig_dims = (3, 2)
    
    #Histogram
    plt.subplot2grid(fig_dims, (0, 0))
    df[attr].hist()
    plt.title(attr+ " Histogram")
    plt.xlabel(attr)
    plt.ylabel('Frequency')

    #Boxplot
    plt.subplot2grid(fig_dims, (0, 1))
    df.boxplot(column=[attr])

# %%
#Bar charts di tutti gli attributi categorici

for attr in cat_attr:            
    fig = plt.figure(figsize=(13, 13)) 
    fig_dims = (3, 2)
    
    #Bar Charts
    plt.subplot2grid(fig_dims, (0, 0))
    df[attr].value_counts().plot(kind='bar',title=attr+" Counts")

# %%
#JobInvolvement Bar chart
perf_dict = {1:"Low", 2:"Medium", 3:"High", 4:"Excellent"}
tmp=df["JobInvolvement"].value_counts(sort=False).rename(index=perf_dict)
tmp.plot(kind='bar',title=" JobInvolvement Counts",rot=0)

# %%
#EnvironmentSatisfaction bar chart
tmp=df["EnvironmentSatisfaction"].value_counts(sort=False).rename(index=perf_dict)
tmp.plot(kind='bar',title=" EnvironmentSatisfaction Counts",rot=0)

# %%
#JobSatisfaction bar chart

tmp=df["JobSatisfaction"].value_counts(sort=False).rename(index=perf_dict)
tmp.plot(kind='bar',title=" JobSatisfaction Counts",rot=0)

# %%
#PerformanceRating bar chart
tmp=df["PerformanceRating"].value_counts(sort=False).rename(index=perf_dict)
tmp.plot(kind='bar',title=" PerformanceRating Counts",rot=0)

# %%
#RelationshipSatisfaction bar chart
tmp=df["RelationshipSatisfaction"].value_counts(sort=False).rename(index=perf_dict)
tmp.plot(kind='bar',title=" RelationshipSatisfaction Counts",rot=0)

# %%
#WorkLifeBalance bar chart
tmp=df["WorkLifeBalance"].value_counts(sort=False).rename(index=perf_dict)
tmp.plot(kind='bar',title=" WorkLifeBalance Counts",rot=0)

# %%
#Education bar chart
edu_dict = {3:'Bachelor',4:'Master',2:'College',1:'Below College',5:'Doctor'}
tmp=df["Education"].value_counts(sort=False).rename(index=edu_dict)
tmp.plot(kind='bar',title=" Education Counts",rot=0)

# %%
#Gender crossx Attrition bar chart (bar chart gender che indica il numero di attrition)
xt = pd.crosstab(df['Gender'],df['Attrition'])
xt.plot(kind='bar', stacked=True, rot=0)
plt.title('Attrition by Gender')
plt.xlabel('Gender')
plt.ylabel('Attrition')
# Out:
# Text(0, 0.5, 'Attrition')

# %%
#MaritalStatus crossx Attrition bar chart (bar chart maritalstatus che indica il numero di attrition)
xt = pd.crosstab(df['MaritalStatus'],df['Attrition'])
xt.plot(kind='bar', stacked=True,rot=0)
plt.title('Attrition by Marital Status')
plt.xlabel('MaritalStatus')
plt.ylabel('Attrition')
# Out:
# Text(0, 0.5, 'Attrition')

# %%
#Education crossx Attrition bar chart (bar chart Education che indica il numero di attrition)
xt = pd.crosstab(df['Education'],df['Attrition'])
xt=xt.rename({3:'Bachelor',4:'Master',2:'College',1:'Below College',5:'Doctor'})
xt.plot(kind='bar', stacked=True, rot=0)

plt.title('Attrition by Education')
plt.xlabel('Education')
plt.ylabel('Attrition')
# Out:
# Text(0, 0.5, 'Attrition')

# %%
#OverTime crossx Attrition bar chart (bar chart overtime che indica il numero di attrition)
xt = pd.crosstab(df['OverTime'],df['Attrition'])
xt=xt.rename({'No':'Without Overtime','Yes':'With Overtime'})
xt.plot(kind='bar', stacked=True, rot=0)

plt.title('Attrition by OverTime')
plt.xlabel('OverTime')
plt.ylabel('Attrition')
# Out:
# Text(0, 0.5, 'Attrition')

# %%
#DistanceFromHome crossx Attrition histogram
df1=df[df['Attrition'] == 'No']['DistanceFromHome']
df2=df[df['Attrition'] == 'Yes']['DistanceFromHome']
plt.hist([df1, df2],stacked=False)
plt.legend(('No', 'Yes'), loc='best')
plt.title('Attrition by Distance from Home Groups Histogram')
plt.xlabel('Distance from Home')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#Age crossx Attrition histogram
df1=df[df['Attrition'] == 'No']['Age']
df2=df[df['Attrition'] == 'Yes']['Age']
plt.hist([df1, df2],stacked=False)
plt.legend(('No', 'Yes'), loc='best')
plt.title('Attrition by Age Groups Histogram')
plt.xlabel('Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#Age crossx Gender histogram
df1=df[df['Gender'] == 'Male']['Age']
df2=df[df['Gender'] == 'Female']['Age']
plt.hist([df1, df2],stacked=False)
plt.legend(('Male', 'Female'), loc='best')
plt.title('Gender by Age Groups Histogram')
plt.xlabel('Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#MonthlyIncome crossx Attrition histogram
df1=df[df['Attrition'] == 'No']['MonthlyIncome']
df2=df[df['Attrition'] == 'Yes']['MonthlyIncome']
max_income=max(df['MonthlyIncome'])
plt.hist([df1, df2],stacked=False)
plt.legend(('No', 'Yes'), loc='best')
plt.title('Attrition by Monthly Income Groups Histogram')
plt.xlabel('Monthly Income')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#YearsAtCompany crossx Attrition histogram
df1=df[df['Attrition'] == 'No']['YearsAtCompany']
df2=df[df['Attrition'] == 'Yes']['YearsAtCompany']
max_income=max(df['YearsAtCompany'])
plt.hist([df1, df2],stacked=False)
plt.legend(('No', 'Yes'), loc='best')
plt.title('Attrition by Years at Company Groups Histogram')
plt.xlabel('Years at Company')
plt.ylabel('Count')
plt.grid(True)

# %%
#TotalWorkingYears crossx Attrition histogram
df1=df[df['Attrition'] == 'No']['TotalWorkingYears']
df2=df[df['Attrition'] == 'Yes']['TotalWorkingYears']
max_income=max(df['TotalWorkingYears'])
plt.hist([df1, df2],stacked=False)
plt.legend(('No', 'Yes'), loc='best')
plt.title('Attrition by Total Working Years Groups Histogram')
plt.xlabel('Total Working Years')
plt.ylabel('Count')
plt.grid(True)

# %%
#TotalWorkingYears crossx Attrition bar chart
xt = pd.crosstab(df['JobSatisfaction'],df['Attrition'])
xt=xt.rename({3:'High',4:'Excelent',2:'Medium',1:'Low'})
xt.plot(kind='bar', stacked=True,rot=0)
plt.title('Attrition by Job Satisfaction')
plt.xlabel('Job Satisfaction')
plt.ylabel('Attrition')
# Out:
# Text(0, 0.5, 'Attrition')

# %%
#RelationshipSatisfaction crossx Attrition bar chart
xt = pd.crosstab(df['RelationshipSatisfaction'],df['Attrition'])
xt=xt.rename({3:'High',4:'Excelent',2:'Medium',1:'Low'})
xt.plot(kind='bar', stacked=True, rot=0)
plt.title('Attrition by Relationship Satisfaction')
plt.xlabel('Relationship Satisfaction')
plt.ylabel('Attrition')
# Out:
# Text(0, 0.5, 'Attrition')

# %%
#WorkLifeBalance crossx Attrition bar chart
xt = pd.crosstab(df['WorkLifeBalance'],df['Attrition'])
xt=xt.rename({3:'High',4:'Excelent',2:'Medium',1:'Low'})
xt.plot(kind='bar', stacked=True, rot=0)
plt.title('Attrition by Worklife Balance')
plt.xlabel('Worklife Balance')
plt.ylabel('Attrition')
# Out:
# Text(0, 0.5, 'Attrition')

# %%
#JobInvolvement crossx Attrition bar chart
xt = pd.crosstab(df['JobInvolvement'],df['Attrition'])
xt=xt.rename({3:'High',4:'Excelent',2:'Medium',1:'Low'})
xt.plot(kind='bar', stacked=True, rot=0)
plt.title('Attrition by Job Involvement')
plt.xlabel('Job Involvement')
plt.ylabel('Attrition')
# Out:
# Text(0, 0.5, 'Attrition')

# %%
#JobRole crossx Attrition bar chart
xt = pd.crosstab(df['JobRole'],df['Attrition'])
xt.plot(kind='bar', stacked=True)
plt.title('Attrition by Job Role')
plt.xlabel('Job Role')
plt.ylabel('Attrition')
# Out:
# Text(0, 0.5, 'Attrition')

# %%
#############################
#ATTRITION CROSS X NORMALIZED
#############################

#MaritalStatus crossx Attrition bar chart normalized
attr='MaritalStatus'
pclass_xt = pd.crosstab(df[attr], df['Attrition'])
pclass_xt_pct = pclass_xt.div(pclass_xt.sum(1).astype(float), axis=0)
pclass_xt_pct.plot(kind='bar', stacked=True,title="Attrition by MaritalStatus",rot=0)
plt.xlabel('MaritalStatus')
plt.ylabel('Attrition (%)')
plt.show()

print(pclass_xt_pct)
# Out:
# Attrition            No       Yes
# MaritalStatus
# Divorced       0.896414  0.103586
# Married        0.876384  0.123616
# Single         0.741514  0.258486

# %%
#EnvironmentSatisfaction crossx Attrition bar chart normalized
attr='EnvironmentSatisfaction'
pclass_xt = pd.crosstab(df[attr], df['Attrition'])
pclass_xt=pclass_xt.rename({3:'High',4:'Excellent',2:'Medium',1:'Low'})
pclass_xt_pct = pclass_xt.div(pclass_xt.sum(1).astype(float), axis=0)
pclass_xt_pct.plot(kind='bar', stacked=True,title="Attrition by "+attr,rot=0)
plt.xlabel(attr)
plt.ylabel('Attrition (%)')
plt.show()

print(pclass_xt_pct)
# Out:
# Attrition                      No       Yes
# EnvironmentSatisfaction
# Low                      0.734513  0.265487
# Medium                   0.858369  0.141631
# High                     0.855191  0.144809
# Excellent                0.868946  0.131054

# %%
#JobInvolvement crossx Attrition bar chart normalized
attr='JobInvolvement'
pclass_xt = pd.crosstab(df[attr], df['Attrition'])
pclass_xt=pclass_xt.rename({3:'High',4:'Excellent',2:'Medium',1:'Low'})
pclass_xt_pct = pclass_xt.div(pclass_xt.sum(1).astype(float), axis=0)
pclass_xt_pct.plot(kind='bar', stacked=True,title="Attrition by "+attr,rot=0)
plt.xlabel(attr)
plt.ylabel('Attrition (%)')
plt.show()

print(pclass_xt_pct)
# Out:
# Attrition             No       Yes
# JobInvolvement
# Low             0.676923  0.323077
# Medium          0.795380  0.204620
# High            0.855685  0.144315
# Excellent       0.918033  0.081967

# %%
#Married Gender crossx Attrition bar chart normalized
attr='OverTime'
pclass_xt = pd.crosstab(df[attr], df['Attrition'])
pclass_xt_pct = pclass_xt.div(pclass_xt.sum(1).astype(float), axis=0)
pclass_xt_pct.plot(kind='bar', stacked=True,title="Attrition by "+attr,rot=0)
plt.xlabel('OverTime')
plt.ylabel('Attrition (%)')
plt.show()

print(pclass_xt_pct)
# Out:
# Attrition        No       Yes
# OverTime
# No         0.893795  0.106205
# Yes        0.695266  0.304734

# %%
#WorkLifeBalance crossx Attrition bar chart normalized
attr='WorkLifeBalance'
pclass_xt = pd.crosstab(df[attr], df['Attrition'])
pclass_xt=pclass_xt.rename({3:'High',4:'Excellent',2:'Medium',1:'Low'})
pclass_xt_pct = pclass_xt.div(pclass_xt.sum(1).astype(float), axis=0)
pclass_xt_pct.plot(kind='bar', stacked=True,title="Attrition by "+attr,rot=0)
plt.xlabel(attr)
plt.ylabel('Attrition (%)')
plt.show()

print(pclass_xt_pct)
# Out:
# Attrition              No       Yes
# WorkLifeBalance
# Low              0.641791  0.358209
# Medium           0.838235  0.161765
# High             0.857939  0.142061
# Excellent        0.815126  0.184874

# %%
#Married Gender crossx Attrition bar chart normalized
attr='Gender'
pclass_xt = pd.crosstab(df[df['MaritalStatus']=='Married'][attr], df['Attrition'])
pclass_xt_pct = pclass_xt.div(pclass_xt.sum(1).astype(float), axis=0)
pclass_xt_pct.plot(kind='bar', stacked=True,title="Attrition by  Married "+attr,rot=0)
plt.xlabel('Married Gender')
plt.ylabel('Attrition')
plt.show()

print(pclass_xt_pct)
# Out:
# Attrition        No       Yes
# Gender
# Female     0.869369  0.130631
# Male       0.885135  0.114865

# %%
#Divorced Gender crossx Attrition bar chart normalized
attr='Gender'
pclass_xt = pd.crosstab(df[df['MaritalStatus']=='Divorced'][attr], df['Attrition'])
pclass_xt_pct = pclass_xt.div(pclass_xt.sum(1).astype(float), axis=0)
pclass_xt_pct.plot(kind='bar', stacked=True,title="Attrition by Divorced "+attr,rot=0)
plt.xlabel('Divorced Gender')
plt.ylabel('Attrition (%)')
plt.show()

print(pclass_xt_pct)
# Out:
# Attrition        No       Yes
# Gender
# Female     0.936170  0.063830
# Male       0.867133  0.132867

# %%
#Jobrole crossx Attrition bar chart normalized
attr='JobRole'
pclass_xt = pd.crosstab(df[attr], df['Attrition'])
pclass_xt_pct = pclass_xt.div(pclass_xt.sum(1).astype(float), axis=0)
pclass_xt_pct.plot(kind='bar', stacked=True,title="Attrition by JobRole",rot=90)
plt.xlabel('JobRole')
plt.ylabel('Attrition (%)')
plt.show()

# %%
#Gender crossx Attrition bar chart normalized
attr='Gender'
pclass_xt = pd.crosstab(df[attr], df['Attrition'])
pclass_xt_pct = pclass_xt.div(pclass_xt.sum(1).astype(float), axis=0)
pclass_xt_pct.plot(kind='bar', stacked=True,title="Attrition by "+attr,rot=0)
plt.xlabel(attr)
plt.ylabel('Attrition (%)')
plt.show()

# %%
#Education crossx Attrition bar chart normalized
attr='Education'
pclass_xt = pd.crosstab(df[attr], df['Attrition'])
pclass_xt_pct = pclass_xt.div(pclass_xt.sum(1).astype(float), axis=0)
pclass_xt_pct.plot(kind='bar', stacked=True,title="Attrition by "+attr,rot=0)
plt.xlabel(attr)
plt.ylabel('Attrition (%)')
plt.show()

# %%
#TotalWorkingYears crossx Attrition bar chart normalized
attr='TotalWorkingYears'
fig = plt.figure(figsize = (15,20))
pclass_xt = pd.crosstab(df[attr], df['Attrition'])
pclass_xt_pct = pclass_xt.div(pclass_xt.sum(1).astype(float), axis=0)
pclass_xt_pct.plot(kind='bar', stacked=True,title="Attrition by "+attr,rot=90)
plt.xticks(fontsize=7)
plt.xlabel(attr)
plt.ylabel('Attrition (%)')
plt.show()

# %%
#Print Correlations matrix before trasformation
f, ax = plt.subplots(figsize=(20, 15))
corr = df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax, annot=True)

# %%
################
#MISSING VALUES#
################
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("./Dataset/Train_HR_Employee_Attrition.csv")


#infer Gender by Gender mode
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])

#infer BusinessTravel by BusinessTravel mode
df['BusinessTravel']=df['BusinessTravel'].fillna(df['BusinessTravel'].mode()[0])

#infer PerformanceRating by PerformanceRating mode
df['PerformanceRating'] = df['PerformanceRating'].fillna(df['PerformanceRating'].mode()[0])

#infer YearsAtCompany by YearsAtCompany mean
df['YearsAtCompany'] = df['YearsAtCompany'].fillna(df['YearsAtCompany'].median())

#infer MonthlyIncome by mean grouped by YearsAtCompany-Quartiles
bins = pd.qcut(df['YearsAtCompany'],[0,0.25,0.50,0.75,1.0])
df['MonthlyIncome'] = df['MonthlyIncome'].groupby(bins).apply(
                      lambda x: x.fillna(x.mean()))

#infer Age by mean grouped by MonthlyIncome-quartiles
bins = pd.qcut(df['MonthlyIncome'],[0,0.25,0.50,0.75,1.0])
df['Age'] = df['Age'].groupby(bins).apply(lambda x: x.fillna(x.mean()))

#TrainingTimesLastYear by fillna with TrainingTimesLastYear values probability
df['TrainingTimesLastYear'] = df['TrainingTimesLastYear'].fillna(df['TrainingTimesLastYear'].mode()[0])

# %%
##########################
#REDUCTION DIMENSIONALITY
##########################

#drop unuseful features
df.drop(["Over18", "StandardHours"], axis=1,inplace=True)

# %%
#Print Correlations matrix before outliers detecting
f, ax = plt.subplots(figsize=(20, 15))
corr = df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax, annot=True)

# %%
#OUTLIERS

fig = plt.figure(figsize=(10, 10)) 
fig_dims = (3, 2)


#Print Monthlyincome histogrsm without outlier replacing
attr="MonthlyIncome"
plt.subplot2grid(fig_dims, (0, 0))
df[attr].hist(bins=np.arange(0,21000,2500))
plt.title('MonthlyIncome')

#MonthlyIncome - Age scatter plot. High income worker aren't noise but really outliers
plt.subplot2grid(fig_dims, (0, 1))
plt.scatter(df['MonthlyIncome'], df['Age'], color='g', marker='*')
plt.xlabel('MonthlyIncome')
plt.ylabel('Age')
plt.legend()

#MonthlyIncome: replacing outliers with q3+1.5*IQR
attr = "MonthlyIncome"
plt.subplot2grid(fig_dims, (1, 0))
q1= df[attr].quantile(0.25)
q3= df[attr].quantile(0.75)
iqr=q3-q1
df_tmp = df.copy()
df_tmp.loc[df[attr]>q3+1.5*iqr, attr] = q3+1.5*iqr
df_tmp[attr].hist(bins=np.arange(0,21000,2500))
plt.title('MonthlyIncome: Outliers replaced with Q3+1.5*IQR')
#df_tmp[attr].describe()

#MonthlyIncome logaritmic trasformation
plt.subplot2grid(fig_dims, (1, 1))
df["MonthlyIncomeTrans"] = np.log(df[attr])
df["MonthlyIncomeTrans"].hist()

#MonthlyIncome logaritmic boxplot
plt.subplot2grid(fig_dims, (2, 0))
df.boxplot(column="MonthlyIncomeTrans")

plt.show()

print(df[attr].describe())
# Out:
# No handles with labels found to put in legend.
# count     1176.000000
# mean      6517.097141
# std       4320.726141
# min       1009.000000
# 25%       3450.750000
# 50%       5238.000000
# 75%       7980.500000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(20, 15))
corr = df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax, annot=True)

# %%
from statistics import mean

#df = pd.read_csv("./Dataset/Attrition.csv")
df['YearsMean'] = None
for index, row in df.iterrows(): 
    df.loc[index, 'YearsMean'] = mean((row['YearsInCurrentRole'], row['YearsSinceLastPromotion'], row['YearsWithCurrManager']))

#df = df.drop(columns = ['YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager'], axis = 'columns')

# %%
f, ax = plt.subplots(figsize=(20, 15))
corr = df.corr()

sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool),
            square=True, ax=ax, annot=True)

# %%
df.to_csv("./Dataset/attrition.csv",index=False)
